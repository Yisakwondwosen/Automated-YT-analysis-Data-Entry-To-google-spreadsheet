# %%
import os
from gspread import service_account
from oauth2client.service_account import ServiceAccountCredentials
import csv

# %%
pip install gspread oauth2client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
creds_path = 'D:\\Downloads\\ytfaceless-videos-2945d11a6940.json'
creds = ServiceAccountCredentials.from_json_keyfile_name(creds_path, scope)
client = gspread.authorize(creds)

spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1SBhFjGkUuo8CItepFC0PgFyRKyyCKO3pOkMErk4D7w4/edit#gid=0'
spreadsheet = client.open_by_url(spreadsheet_url)

worksheet = spreadsheet.sheet1

headers = ['Video Title', 'Title Structure', 'Thumbnail', 'Text used on thumbnail', 'Outlier Score', 'Link to video']

worksheet.clear()

worksheet.append_row(headers)


print("Columns have been created in the spreadsheet.")
# Out:
# Columns have been created in the spreadsheet.

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

def insert_titles_with_pagination(worksheet, video_titles, batch_size=100):
    # Split the list into batches of the specified size
    total_titles = len(video_titles)
    for i in range(0, total_titles, batch_size):
        batch = video_titles[i:i + batch_size]
        # Insert the batch into the worksheet
        worksheet.append_rows([[title] for title in batch])  # Ensure each title is in its own row

def main():
    # Example video titles (truncated for brevity)
    video_titles = [
        "All current Residence Massacre badges (Roblox)",
    "Roblox Residence Massacre All 13 Badge Showcase And How To Get It Tutorial",
    "ROBLOX - Residence Massacre All Jumpscare",
    "Roblox Residence Massacre (Animation) (Part 1)",
    "Roblox Residence Massacre (Animation) (Part 2)",
    "ROBLOX Residence Massacre Funny Moments (MEMES) #1",
    "How To Get All Badges In Raise A Kenny (Roblox)",
    "Residence Massacre Jumpscare Animation Stick Nodes",
    "Roblox Redwood prison",
    "Radiant Residents - Ending 1 - Full Walkthrough - Roblox",
    "Roblox Doors All Jumpscares... (Maxed Graphics and BRIGHTENED)",
    "The Intruder - The House - Nightmare - Full Walkthrough - Roblox",
    "ALL ROBLOX PROMOCODES (2014 - 2021)",
    "ALL Doors MONSTERS Crucifix Roblox",
    "Roblox | Brookhaven RP | ALL OF US ARE DEAD",
    "Roblox Youtube: The Bad Guys",
    "Grand Kaizen CODES - ROBLOX 2023",
    "How to get ALL the Twice Emotes in roblox",
    "ROBLOX-Broken Bones 2:All Secret Maps.",
    "The Silent Screams of Bloxburg | Roblox Movie",
    "A Roblox Psychological Horror Game.",
    "Roblox Youtube: The Bad Guys",
    "(kinda..) ALL OF THE ROBLOX VR GAMES",
    "The Silent Screams of Bloxburg | Roblox Movie",
    "Grand Kaizen CODES - ROBLOX 2023",
    "The Darkest Horror Game on Roblox",
    "The Intruder - The House - Nightmare - Full Walkthrough - Roblox",
    "The Hotel Has Changed! Also Crucifixion, yes. | Roblox Doors Hotel Update",
    "ONE COLOR Hide & Seek In ROBLOX!",
    "DOORS: The Movie: A Roblox Horror Movie",
    "Escape EVIL LUNCH LADY OBBY in Roblox",
    "Top 13 Roblox Horror Games to play with friends (Roblox horror games multiplayer)",
    "ROBLOX DEVELOPERS AS THE SEVEN DEADLY SINS",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "Roblox Games You've Probably Forgot About..",
    "Roblox the presentation experience: more robux actions and some chaos",
    "Roblox | Brookhaven RP | ALL OF US ARE DEAD",
    "How to get ALL the Twice Emotes in roblox",
    "How To FIND ALL 7 NEW UPDATE FOOD LOCATIONS In Roblox Secret Staycation!",
    "😱 All NEW CODES In Super League Soccer! 😱 | ROBLOX",
    "ROBLOX - Weird Strict Dad All Jumpscares and Scary Moments",
    "All Roblox Error Codes (Explained)",
    "Roblox Games You've Probably Forgot About..",
    "Roblox the presentation experience: more robux actions and some chaos",
    "This Ghost Has The Finger Painter Badge...",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "Roblox The Mimic All Books Jumpscare (Including Jigoku, NM mode, Game mode)",
    "ROBLOX : IT'S FREE",
    "ROBLOX-Broken Bones 2:All Secret Maps.",
    "ROBLOX - IShowSpeed got BILLIONS of Robux reaction",
    "ESCAPE BARKY THE DOG OBBY | Roblox",
    "10 Best Roblox Horror Games 2022 (Scary Roblox Games)",
    "ONE COLOR Hide & Seek In ROBLOX!",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "Dude Theft Wars All The Ghost In This Game !!! 👻👻👻",
    "The Watchtower Experience - Roblox -[All Endings]",
    "How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation",
    "ROBLOX NPCs are becoming smart! - 5 NEW Halloween Endings",
    "POV: Scary Jane (The Fake Mary) realizes you maxed your stats. Roblox Break In Chapter 2",
    "How to beat Residence Massacre Night 1 Without Bugs",
    "10 Best Roblox Horror Games 2022 (Scary Roblox Games)",
    "ALL 21 BOOMBOX CODES 2021 | Roblox Animal Simulator",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "DOORS: The Movie: A Roblox Horror Movie",
    "The Darkest Horror Game on Roblox",
    "How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation",
    "GIVING PEOPLE THE WORST HAIRCUTS IN ROBLOX NEIGHBORS..",
    "The Hotel Has Changed! Also Crucifixion, yes. | Roblox Doors Hotel Update",
    "The Watchtower Experience - Roblox -[All Endings]",
    "Trapped in GIRLS ONLY Prison! (Roblox)",
    "How to get the Back On Track badge(detailed guide with info on a-60,a-90 & a-120) | DOORS ROBLOX",
    "How to get titan assistance badge! in Skbidi Toilet RP Roblox.",
    "Me and my family did this trend Part 2",
    "ROBLOX Brookhaven 🏡RP - FUNNY MOMENTS: RICH and POOR Full Episodes 4",
    "ROBLOX - Weird Strict Dad All Jumpscares and Scary Moments",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "HOW TO GET 'Haunted Harvester' FOR FREE! - Blade Ball (Roblox)",
    "Roblox The Mimic All Books Jumpscare (Including Jigoku, NM mode, Game mode)",
    "Roblox raise a floppa Full Game",
    "TOP 30 *WORKING* 2023 BLOXBURG NEIGHBORHOOD CODES!! | Roblox Bloxburg",
    "I Played 50 Roblox Anime Games",
    "The 10 strangest secrets in - break in 2 | Roblox",
    "ROBLOX - Faithless [ALL ENDINGS] - [Full Walkthrough]",
    "this roblox game FINALLY updated...",
    "How To Redeem Rogold Ultimate (Roblox)",
    "Mortal Kombat 1 - ALL Omni-Man Skins and Gears",
    "Obby But You're on a Car in Roblox",
    "I Escaped From Barry's Prison | Roblox Gameplay",
    "Hogwarts Legacy - Visiting Azkaban",
    "[ROBLOX UPDATES] FREE MINI PLUSHIES / FREE HAIR / FREE EMOTES / FREE HEADLESS 🤩👏",
    "Assassin's Creed - Every Iconic Assassinations",
    "5 *NEW* PLS DONATE GIFTBUX CODES IN ROBLOX 2023",
    "😱 All NEW CODES In Super League Soccer! 😱 | ROBLOX",
    "FASTEST WAY To Get Your FIRST 4K And 20 BOMB BADGES - Apex Legends!!",
    "SECRET UPDATE | POLICE GIRL RIP? Police Family Escape (OBBY) Full Game ROBLOX #roblox #obby",
    "LOCKDOWN (Roblox Movie) | Brookhaven RP",
    "Speaker family only challenge (Roblox Toilet Tower Defense)",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "How to make a Citation System ( ROBLOX )",
    "Top 10 NEW Scary Roblox Games in 2022",
    "Malk (Interminable Rooms Meme)",
    "they live in a HAUNTED HOUSE",
    "Buying EVERY Vehicle and Car in ROBLOX Vehicle Legends!",
    "I Played 50 Roblox Anime Games",
    "How To Get SSJ Rage In Dragon Soul | Roblox",
    "Roblox Outfit Ideas Compilation #1",
    "Roblox: GREAT SCHOOL BREAKOUT Hardmode 1st POV",
    "Hanafi Muslim Massacre"
    ]

    # Set up the Google Sheets client
    scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
    creds_path = 'D:\\Downloads\\ytfaceless-videos-2945d11a6940.json'
    creds = ServiceAccountCredentials.from_json_keyfile_name(creds_path, scope)
    client = gspread.authorize(creds)

    # Open the spreadsheet by key
    spreadsheet_key = '1SBhFjGkUuo8CItepFC0PgFyRKyyCKO3pOkMErk4D7w4'
    spreadsheet = client.open_by_key(spreadsheet_key)

    # Assuming you want to insert the titles into the first worksheet
    worksheet = spreadsheet.sheet1

    # Insert video titles into the worksheet with pagination
    insert_titles_with_pagination(worksheet, video_titles, batch_size=50)

if __name__ == '__main__':
    main()

# %%
video_titles = [
    "All current Residence Massacre badges (Roblox)",
    "Roblox Residence Massacre All 13 Badge Showcase And How To Get It Tutorial",
    "ROBLOX - Residence Massacre All Jumpscare",
    "Roblox Residence Massacre (Animation) (Part 1)",
    "Roblox Residence Massacre (Animation) (Part 2)",
    "ROBLOX Residence Massacre Funny Moments (MEMES) #1",
    "How To Get All Badges In Raise A Kenny (Roblox)",
    "Residence Massacre Jumpscare Animation Stick Nodes",
    "Roblox Redwood prison",
    "Radiant Residents - Ending 1 - Full Walkthrough - Roblox",
    "Roblox Doors All Jumpscares... (Maxed Graphics and BRIGHTENED)",
    "The Intruder - The House - Nightmare - Full Walkthrough - Roblox",
    "ALL ROBLOX PROMOCODES (2014 - 2021)",
    "ALL Doors MONSTERS Crucifix Roblox",
    "Roblox | Brookhaven RP | ALL OF US ARE DEAD",
    "Roblox Youtube: The Bad Guys",
    "Grand Kaizen CODES - ROBLOX 2023",
    "How to get ALL the Twice Emotes in roblox",
    "ROBLOX-Broken Bones 2:All Secret Maps.",
    "The Silent Screams of Bloxburg | Roblox Movie",
    "A Roblox Psychological Horror Game.",
    "Roblox Youtube: The Bad Guys",
    "(kinda..) ALL OF THE ROBLOX VR GAMES",
    "The Silent Screams of Bloxburg | Roblox Movie",
    "Grand Kaizen CODES - ROBLOX 2023",
    "The Darkest Horror Game on Roblox",
    "The Intruder - The House - Nightmare - Full Walkthrough - Roblox",
    "The Hotel Has Changed! Also Crucifixion, yes. | Roblox Doors Hotel Update",
    "ONE COLOR Hide & Seek In ROBLOX!",
    "DOORS: The Movie: A Roblox Horror Movie",
    "Escape EVIL LUNCH LADY OBBY in Roblox",
    "Top 13 Roblox Horror Games to play with friends (Roblox horror games multiplayer)",
    "ROBLOX DEVELOPERS AS THE SEVEN DEADLY SINS",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "Roblox Games You've Probably Forgot About..",
    "Roblox the presentation experience: more robux actions and some chaos",
    "Roblox | Brookhaven RP | ALL OF US ARE DEAD",
    "How to get ALL the Twice Emotes in roblox",
    "How To FIND ALL 7 NEW UPDATE FOOD LOCATIONS In Roblox Secret Staycation!",
    "😱 All NEW CODES In Super League Soccer! 😱 | ROBLOX",
    "ROBLOX - Weird Strict Dad All Jumpscares and Scary Moments",
    "All Roblox Error Codes (Explained)",
    "Roblox Games You've Probably Forgot About..",
    "Roblox the presentation experience: more robux actions and some chaos",
    "This Ghost Has The Finger Painter Badge...",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "Roblox The Mimic All Books Jumpscare (Including Jigoku, NM mode, Game mode)",
    "ROBLOX : IT'S FREE",
    "ROBLOX-Broken Bones 2:All Secret Maps.",
    "ROBLOX - IShowSpeed got BILLIONS of Robux reaction",
    "ESCAPE BARKY THE DOG OBBY | Roblox",
    "10 Best Roblox Horror Games 2022 (Scary Roblox Games)",
    "ONE COLOR Hide & Seek In ROBLOX!",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "Dude Theft Wars All The Ghost In This Game !!! 👻👻👻",
    "The Watchtower Experience - Roblox -[All Endings]",
    "How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation",
    "ROBLOX NPCs are becoming smart! - 5 NEW Halloween Endings",
    "POV: Scary Jane (The Fake Mary) realizes you maxed your stats. Roblox Break In Chapter 2",
    "How to beat Residence Massacre Night 1 Without Bugs",
    "10 Best Roblox Horror Games 2022 (Scary Roblox Games)",
    "ALL 21 BOOMBOX CODES 2021 | Roblox Animal Simulator",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "DOORS: The Movie: A Roblox Horror Movie",
    "The Darkest Horror Game on Roblox",
    "How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation",
    "GIVING PEOPLE THE WORST HAIRCUTS IN ROBLOX NEIGHBORS..",
    "The Hotel Has Changed! Also Crucifixion, yes. | Roblox Doors Hotel Update",
    "The Watchtower Experience - Roblox -[All Endings]",
    "Trapped in GIRLS ONLY Prison! (Roblox)",
    "How to get the Back On Track badge(detailed guide with info on a-60,a-90 & a-120) | DOORS ROBLOX",
    "How to get titan assistance badge! in Skbidi Toilet RP Roblox.",
    "Me and my family did this trend Part 2",
    "ROBLOX Brookhaven 🏡RP - FUNNY MOMENTS: RICH and POOR Full Episodes 4",
    "ROBLOX - Weird Strict Dad All Jumpscares and Scary Moments",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "HOW TO GET 'Haunted Harvester' FOR FREE! - Blade Ball (Roblox)",
    "Roblox The Mimic All Books Jumpscare (Including Jigoku, NM mode, Game mode)",
    "Roblox raise a floppa Full Game",
    "TOP 30 *WORKING* 2023 BLOXBURG NEIGHBORHOOD CODES!! | Roblox Bloxburg",
    "I Played 50 Roblox Anime Games",
    "The 10 strangest secrets in - break in 2 | Roblox",
    "ROBLOX - Faithless [ALL ENDINGS] - [Full Walkthrough]",
    "this roblox game FINALLY updated...",
    "How To Redeem Rogold Ultimate (Roblox)",
    "Mortal Kombat 1 - ALL Omni-Man Skins and Gears",
    "Obby But You're on a Car in Roblox",
    "I Escaped From Barry's Prison | Roblox Gameplay",
    "Hogwarts Legacy - Visiting Azkaban",
    "[ROBLOX UPDATES] FREE MINI PLUSHIES / FREE HAIR / FREE EMOTES / FREE HEADLESS 🤩👏",
    "Assassin's Creed - Every Iconic Assassinations",
    "5 *NEW* PLS DONATE GIFTBUX CODES IN ROBLOX 2023",
    "😱 All NEW CODES In Super League Soccer! 😱 | ROBLOX",
    "FASTEST WAY To Get Your FIRST 4K And 20 BOMB BADGES - Apex Legends!!",
    "SECRET UPDATE | POLICE GIRL RIP? Police Family Escape (OBBY) Full Game ROBLOX #roblox #obby",
    "LOCKDOWN (Roblox Movie) | Brookhaven RP",
    "Speaker family only challenge (Roblox Toilet Tower Defense)",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "How to make a Citation System ( ROBLOX )",
    "Top 10 NEW Scary Roblox Games in 2022",
    "Malk (Interminable Rooms Meme)",
    "they live in a HAUNTED HOUSE",
    "Buying EVERY Vehicle and Car in ROBLOX Vehicle Legends!",
    "I Played 50 Roblox Anime Games",
    "How To Get SSJ Rage In Dragon Soul | Roblox",
    "Roblox Outfit Ideas Compilation #1",
    "Roblox: GREAT SCHOOL BREAKOUT Hardmode 1st POV",
    "Hanafi Muslim Massacre"
]

# Categorize titles
tutorial_videos = []
animation_videos = []
funny_videos = []
jumpscare_videos = []
badge_videos = []

for title in video_titles:
    if "tutorial" in title.lower() or "how to" in title.lower():
        tutorial_videos.append(title)
    if "animation" in title.lower():
        animation_videos.append(title)
    if "funny" in title.lower() or "memes" in title.lower():
        funny_videos.append(title)
    if "jumpscare" in title.lower():
        jumpscare_videos.append(title)
    if "badge" in title.lower():
        badge_videos.append(title)

# Print categorized lists
print("Tutorial Videos:")
print(tutorial_videos)
print("\nAnimation Videos:")
print(animation_videos)
print("\nFunny Videos:")
print(funny_videos)
print("\nJumpscare Videos:")
print(jumpscare_videos)
print("\nBadge Videos:")
print(badge_videos)
# Out:
# Tutorial Videos:
# ['Roblox Residence Massacre All 13 Badge Showcase And How To Get It Tutorial', 'How To Get All Badges In Raise A Kenny (Roblox)', 'How to get ALL the Twice Emotes in roblox', 'How to get ALL the Twice Emotes in roblox', 'How To FIND ALL 7 NEW UPDATE FOOD LOCATIONS In Roblox Secret Staycation!', 'How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation', 'How to beat Residence Massacre Night 1 Without Bugs', 'How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation', 'How to get the Back On Track badge(detailed guide with info on a-60,a-90 & a-120) | DOORS ROBLOX', 'How to get titan assistance badge! in Skbidi Toilet RP Roblox.', "HOW TO GET 'Haunted Harvester' FOR FREE! - Blade Ball (Roblox)", 'How To Redeem Rogold Ultimate (Roblox)', 'How to make a Citation System ( ROBLOX )', 'How To Get SSJ Rage In Dragon Soul | Roblox']
#
# Animation Videos:
# ...

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

def youtube_search(api_key, query):
    youtube = build('youtube', 'v3', developerKey=api_key)

    # Search for videos by title
    search_response = youtube.search().list(
        q=query,
        part='id,snippet',
        maxResults=1,
        type='video'
    ).execute()

    videos = []

    for search_result in search_response.get('items', []):
        video_id = search_result['id']['videoId']
        title = search_result['snippet']['title']
        thumbnails = search_result['snippet']['thumbnails']['default']['url']
        videos.append((title, video_id, thumbnails))

    return videos

def main():
    api_key = 'AIzaSyASU-FIyW1_p5kVkTYVcg-jrq4d-e51Z9I'  # Your YouTube API key
    video_titles = [
       "All current Residence Massacre badges (Roblox)",
    "Roblox Residence Massacre All 13 Badge Showcase And How To Get It Tutorial",
    "ROBLOX - Residence Massacre All Jumpscare",
    "Roblox Residence Massacre (Animation) (Part 1)",
    "Roblox Residence Massacre (Animation) (Part 2)",
    "ROBLOX Residence Massacre Funny Moments (MEMES) #1",
    "How To Get All Badges In Raise A Kenny (Roblox)",
    "Residence Massacre Jumpscare Animation Stick Nodes",
    "Roblox Redwood prison",
    "Radiant Residents - Ending 1 - Full Walkthrough - Roblox",
    "Roblox Doors All Jumpscares... (Maxed Graphics and BRIGHTENED)",
    "The Intruder - The House - Nightmare - Full Walkthrough - Roblox",
    "ALL ROBLOX PROMOCODES (2014 - 2021)",
    "ALL Doors MONSTERS Crucifix Roblox",
    "Roblox | Brookhaven RP | ALL OF US ARE DEAD",
    "Roblox Youtube: The Bad Guys",
    "Grand Kaizen CODES - ROBLOX 2023",
    "How to get ALL the Twice Emotes in roblox",
    "ROBLOX-Broken Bones 2:All Secret Maps.",
    "The Silent Screams of Bloxburg | Roblox Movie",
    "A Roblox Psychological Horror Game.",
    "Roblox Youtube: The Bad Guys",
    "(kinda..) ALL OF THE ROBLOX VR GAMES",
    "The Silent Screams of Bloxburg | Roblox Movie",
    "Grand Kaizen CODES - ROBLOX 2023",
    "The Darkest Horror Game on Roblox",
    "The Intruder - The House - Nightmare - Full Walkthrough - Roblox",
    "The Hotel Has Changed! Also Crucifixion, yes. | Roblox Doors Hotel Update",
    "ONE COLOR Hide & Seek In ROBLOX!",
    "DOORS: The Movie: A Roblox Horror Movie",
    "Escape EVIL LUNCH LADY OBBY in Roblox",
    "Top 13 Roblox Horror Games to play with friends (Roblox horror games multiplayer)",
    "ROBLOX DEVELOPERS AS THE SEVEN DEADLY SINS",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "Roblox Games You've Probably Forgot About..",
    "Roblox the presentation experience: more robux actions and some chaos",
    "Roblox | Brookhaven RP | ALL OF US ARE DEAD",
    "How to get ALL the Twice Emotes in roblox",
    "How To FIND ALL 7 NEW UPDATE FOOD LOCATIONS In Roblox Secret Staycation!",
    "😱 All NEW CODES In Super League Soccer! 😱 | ROBLOX",
    "ROBLOX - Weird Strict Dad All Jumpscares and Scary Moments",
    "All Roblox Error Codes (Explained)",
    "Roblox Games You've Probably Forgot About..",
    "Roblox the presentation experience: more robux actions and some chaos",
    "This Ghost Has The Finger Painter Badge...",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "Roblox The Mimic All Books Jumpscare (Including Jigoku, NM mode, Game mode)",
    "ROBLOX : IT'S FREE",
    "ROBLOX-Broken Bones 2:All Secret Maps.",
    "ROBLOX - IShowSpeed got BILLIONS of Robux reaction",
    "ESCAPE BARKY THE DOG OBBY | Roblox",
    "10 Best Roblox Horror Games 2022 (Scary Roblox Games)",
    "ONE COLOR Hide & Seek In ROBLOX!",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "Dude Theft Wars All The Ghost In This Game !!! 👻👻👻",
    "The Watchtower Experience - Roblox -[All Endings]",
    "How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation",
    "ROBLOX NPCs are becoming smart! - 5 NEW Halloween Endings",
    "POV: Scary Jane (The Fake Mary) realizes you maxed your stats. Roblox Break In Chapter 2",
    "How to beat Residence Massacre Night 1 Without Bugs",
    "10 Best Roblox Horror Games 2022 (Scary Roblox Games)",
    "ALL 21 BOOMBOX CODES 2021 | Roblox Animal Simulator",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "DOORS: The Movie: A Roblox Horror Movie",
    "The Darkest Horror Game on Roblox",
    "How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation",
    "GIVING PEOPLE THE WORST HAIRCUTS IN ROBLOX NEIGHBORS..",
    "The Hotel Has Changed! Also Crucifixion, yes. | Roblox Doors Hotel Update",
    "The Watchtower Experience - Roblox -[All Endings]",
    "Trapped in GIRLS ONLY Prison! (Roblox)",
    "How to get the Back On Track badge(detailed guide with info on a-60,a-90 & a-120) | DOORS ROBLOX",
    "How to get titan assistance badge! in Skbidi Toilet RP Roblox.",
    "Me and my family did this trend Part 2",
    "ROBLOX Brookhaven 🏡RP - FUNNY MOMENTS: RICH and POOR Full Episodes 4",
    "ROBLOX - Weird Strict Dad All Jumpscares and Scary Moments",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "HOW TO GET 'Haunted Harvester' FOR FREE! - Blade Ball (Roblox)",
    "Roblox The Mimic All Books Jumpscare (Including Jigoku, NM mode, Game mode)",
    "Roblox raise a floppa Full Game",
    "TOP 30 *WORKING* 2023 BLOXBURG NEIGHBORHOOD CODES!! | Roblox Bloxburg",
    "I Played 50 Roblox Anime Games",
    "The 10 strangest secrets in - break in 2 | Roblox",
    "ROBLOX - Faithless [ALL ENDINGS] - [Full Walkthrough]",
    "this roblox game FINALLY updated...",
    "How To Redeem Rogold Ultimate (Roblox)",
    "Mortal Kombat 1 - ALL Omni-Man Skins and Gears",
    "Obby But You're on a Car in Roblox",
    "I Escaped From Barry's Prison | Roblox Gameplay",
    "Hogwarts Legacy - Visiting Azkaban",
    "[ROBLOX UPDATES] FREE MINI PLUSHIES / FREE HAIR / FREE EMOTES / FREE HEADLESS 🤩👏",
    "Assassin's Creed - Every Iconic Assassinations",
    "5 *NEW* PLS DONATE GIFTBUX CODES IN ROBLOX 2023",
    "😱 All NEW CODES In Super League Soccer! 😱 | ROBLOX",
    "FASTEST WAY To Get Your FIRST 4K And 20 BOMB BADGES - Apex Legends!!",
    "SECRET UPDATE | POLICE GIRL RIP? Police Family Escape (OBBY) Full Game ROBLOX #roblox #obby",
    "LOCKDOWN (Roblox Movie) | Brookhaven RP",
    "Speaker family only challenge (Roblox Toilet Tower Defense)",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "How to make a Citation System ( ROBLOX )",
    "Top 10 NEW Scary Roblox Games in 2022",
    "Malk (Interminable Rooms Meme)",
    "they live in a HAUNTED HOUSE",
    "Buying EVERY Vehicle and Car in ROBLOX Vehicle Legends!",
    "I Played 50 Roblox Anime Games",
    "How To Get SSJ Rage In Dragon Soul | Roblox",
    "Roblox Outfit Ideas Compilation #1",
    "Roblox: GREAT SCHOOL BREAKOUT Hardmode 1st POV",
    "Hanafi Muslim Massacre"
    ]

    for title in video_titles:
        try:
            results = youtube_search(api_key, title)
            for result in results:
                print(f"Title: {result[0]}, Video ID: {result[1]}, Thumbnail: {result[2]}")
        except HttpError as e:
            print(f"An HTTP error {e.resp.status} occurred:\n{e.content}")

if __name__ == '__main__':
    main()
# Out:
# Title: How to get ALL 11 NIGHT 2 BADGES in Residence Massacre with TUTORIAL [Roblox], Video ID: DpbU-V7NCVo, Thumbnail: https://i.ytimg.com/vi/DpbU-V7NCVo/default.jpg
# Title: Roblox Residence Massacre All 13 Badge Showcase And How To Get It Tutorial, Video ID: XVcgZWViV20, Thumbnail: https://i.ytimg.com/vi/XVcgZWViV20/default.jpg
# Title: All Entities/Jumpscares - Residence Massacre Night 2 Roblox, Video ID: PGFlAAXy67c, Thumbnail: https://i.ytimg.com/vi/PGFlAAXy67c/default.jpg
# Title: Roblox Residence Massacre (Animation) (Part 1), Video ID: w5d0w5tCxF0, Thumbnail: https://i.ytimg.com/vi/w5d0w5tCxF0/default.jpg
# Title: Roblox Residence Massacre (Animation) (Part 2), Video ID: vM7-Su9o-K4, Thumbnail: https://i.ytimg.com/vi/vM7-Su9o-K4/default.jpg
# Title: ROBLOX Residence Massacre Funny Moments (MEMES) #1, Video ID: yqHcHoWwqGY, Thumbnail: https://i.ytimg.com/vi/yqHcHoWwqGY/default.jpg
# ...

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import pandas as pd

def youtube_search(api_key, query):
    youtube = build('youtube', 'v3', developerKey=api_key)
    try:
        search_response = youtube.search().list(
            q=query,
            part='id,snippet',
            maxResults=1,
            type='video'
        ).execute()

        videos = []
        for search_result in search_response.get('items', []):
            video_id = search_result['id']['videoId']
            title = search_result['snippet']['title']
            thumbnails = search_result['snippet']['thumbnails']['default']['url']
            videos.append((title, video_id, thumbnails))
        return videos
    except HttpError as e:
        print(f"An HTTP error {e.resp.status} occurred:\n{e.content}")
        return []

def main():
    api_key = 'AIzaSyASU-FIyW1_p5kVkTYVcg-jrq4d-e51Z9I'  # Your YouTube API key
    video_titles = [
        "All current Residence Massacre badges (Roblox)",
        "Roblox Residence Massacre All 13 Badge Showcase And How To Get It Tutorial",
        # Add other titles as needed
    ]

    all_videos = []
    for title in video_titles:
        results = youtube_search(api_key, title)
        all_videos.extend(results)

    # Create a DataFrame from the video data
    df = pd.DataFrame(all_videos, columns=['Title', 'Video ID', 'Thumbnail URL'])

    # Save the DataFrame to an Excel file
    df.to_excel('youtube_thumbnails.xlsx', index=False)

    print("Data saved to 'youtube_thumbnails.xlsx'.")

if __name__ == '__main__':
    main()
# Out:
# An HTTP error 403 occurred:
# b'{\n  "error": {\n    "code": 403,\n    "message": "The request cannot be completed because you have exceeded your \\u003ca href=\\"/youtube/v3/getting-started#quota\\"\\u003equota\\u003c/a\\u003e.",\n    "errors": [\n      {\n        "message": "The request cannot be completed because you have exceeded your \\u003ca href=\\"/youtube/v3/getting-started#quota\\"\\u003equota\\u003c/a\\u003e.",\n        "domain": "youtube.quota",\n        "reason": "quotaExceeded"\n      }\n    ]\n  }\n}\n'
# An HTTP error 403 occurred:
# ...

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

def append_to_sheet(worksheet, category, data, start_row, start_col):
    # Append category name
    worksheet.update_cell(start_row, start_col, category)
    # Append data items, each in a new row under the category
    for i, item in enumerate(data):
        worksheet.update_cell(start_row + i + 1, start_col, item)

def main():
    # Categorized video titles
    tutorial_videos = [
        "Roblox Residence Massacre All 13 Badge Showcase And How To Get It Tutorial",
        "How To Get All Badges In Raise A Kenny (Roblox)",
        "How to get ALL the Twice Emotes in roblox",
        "How to get ALL the Twice Emotes in roblox",
        "How To FIND ALL 7 NEW UPDATE FOOD LOCATIONS In Roblox Secret Staycation!",
        "How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation",
        "How to beat Residence Massacre Night 1 Without Bugs",
        "How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation",
        "How to get the Back On Track badge(detailed guide with info on a-60,a-90 & a-120) | DOORS ROBLOX",
        "How to get titan assistance badge! in Skbidi Toilet RP Roblox.",
        "HOW TO GET 'Haunted Harvester' FOR FREE! - Blade Ball (Roblox)",
        "How To Redeem Rogold Ultimate (Roblox)",
        "How to make a Citation System ( ROBLOX )",
        "How To Get SSJ Rage In Dragon Soul | Roblox"
    ]
    animation_videos = [
        "Roblox Residence Massacre (Animation) (Part 1)",
        "Roblox Residence Massacre (Animation) (Part 2)",
        "Residence Massacre Jumpscare Animation Stick Nodes"
    ]
    funny_videos = [
        "ROBLOX Residence Massacre Funny Moments (MEMES) #1",
        "ROBLOX Brookhaven 🏡RP - FUNNY MOMENTS: RICH and POOR Full Episodes 4"
    ]
    jumpscare_videos = [
        "ROBLOX - Residence Massacre All Jumpscare",
        "Residence Massacre Jumpscare Animation Stick Nodes",
        "Roblox Doors All Jumpscares... (Maxed Graphics and BRIGHTENED)",
        "ROBLOX - Weird Strict Dad All Jumpscares and Scary Moments",
        "Roblox The Mimic All Books Jumpscare (Including Jigoku, NM mode, Game mode)",
        "ROBLOX - Weird Strict Dad All Jumpscares and Scary Moments",
        "Roblox The Mimic All Books Jumpscare (Including Jigoku, NM mode, Game mode)"
    ]
    badge_videos = [
        "All current Residence Massacre badges (Roblox)",
        "Roblox Residence Massacre All 13 Badge Showcase And How To Get It Tutorial",
        "How To Get All Badges In Raise A Kenny (Roblox)",
        "This Ghost Has The Finger Painter Badge...",
        "How to get the Back On Track badge(detailed guide with info on a-60,a-90 & a-120) | DOORS ROBLOX",
        "How to get titan assistance badge! in Skbidi Toilet RP Roblox.",
        "FASTEST WAY To Get Your FIRST 4K And 20 BOMB BADGES - Apex Legends!!"
    ]
    # Set up the Google Sheets client
    scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
    creds_path = 'path_to_your_credentials_file.json'
    creds = ServiceAccountCredentials.from_json_keyfile_name(creds_path, scope)
    client = gspread.authorize(creds)

    # Open the spreadsheet by key
    spreadsheet_key = '1SBhFjGkUuo8CItepFC0PgFyRKyyCKO3pOkMErk4D7w4'
    spreadsheet = client.open_by_key(spreadsheet_key)

    # Select "Sheet2" by title
    worksheet = spreadsheet.worksheet("Sheet2")

    # Append data to "Sheet2"
    append_to_sheet(worksheet, "Tutorial Videos", tutorial_videos, 2, 2)
    append_to_sheet(worksheet, "Animation Videos", animation_videos, 2, 3)
    append_to_sheet(worksheet, "Funny Videos", funny_videos, 2, 4)
    append_to_sheet(worksheet, "Jumpscare Videos", jumpscare_videos, 2, 5)
    append_to_sheet(worksheet, "Badge Videos", badge_videos, 2, 6)

if __name__ == '__main__':
    main()

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import json

# Assuming you have a simple JSON file for caching: cache_file.json
def load_cache():
    try:
        with open('cache_file.json', 'r') as file:
            return json.load(file)
    except FileNotFoundError:
        return {}

def save_cache(cache):
    with open('cache_file.json', 'w') as file:
        json.dump(cache, file)

def youtube_search(api_key, query, cache):
    if query in cache:
        print("Using cached data")
        return cache[query]

    youtube = build('youtube', 'v3', developerKey=api_key)
    try:
        search_response = youtube.search().list(
            q=query,
            part='id,snippet',
            maxResults=1,
            type='video'
        ).execute()

        videos = []
        for search_result in search_response.get('items', []):
            video_id = search_result['id']['videoId']
            title = search_result['snippet']['title']
            thumbnails = search_result['snippet']['thumbnails']['default']['url']
            videos.append((title, video_id, thumbnails))
        
        cache[query] = videos
        return videos
    except HttpError as e:
        print(f"An HTTP error {e.resp.status} occurred:\n{e.content}")
        return []

def main():
    api_key = 'AIzaSyASU-FIyW1_p5kVkTYVcg-jrq4d-e51Z9I'
    video_titles = [
        "All current Residence Massacre badges (Roblox)",
    "Roblox Residence Massacre All 13 Badge Showcase And How To Get It Tutorial",
    "ROBLOX - Residence Massacre All Jumpscare",
    "Roblox Residence Massacre (Animation) (Part 1)",
    "Roblox Residence Massacre (Animation) (Part 2)",
    "ROBLOX Residence Massacre Funny Moments (MEMES) #1",
    "How To Get All Badges In Raise A Kenny (Roblox)",
    "Residence Massacre Jumpscare Animation Stick Nodes",
    "Roblox Redwood prison",
    "Radiant Residents - Ending 1 - Full Walkthrough - Roblox",
    "Roblox Doors All Jumpscares... (Maxed Graphics and BRIGHTENED)",
    "The Intruder - The House - Nightmare - Full Walkthrough - Roblox",
    "ALL ROBLOX PROMOCODES (2014 - 2021)",
    "ALL Doors MONSTERS Crucifix Roblox",
    "Roblox | Brookhaven RP | ALL OF US ARE DEAD",
    "Roblox Youtube: The Bad Guys",
    "Grand Kaizen CODES - ROBLOX 2023",
    "How to get ALL the Twice Emotes in roblox",
    "ROBLOX-Broken Bones 2:All Secret Maps.",
    "The Silent Screams of Bloxburg | Roblox Movie",
    "A Roblox Psychological Horror Game.",
    "Roblox Youtube: The Bad Guys",
    "(kinda..) ALL OF THE ROBLOX VR GAMES",
    "The Silent Screams of Bloxburg | Roblox Movie",
    "Grand Kaizen CODES - ROBLOX 2023",
    "The Darkest Horror Game on Roblox",
    "The Intruder - The House - Nightmare - Full Walkthrough - Roblox",
    "The Hotel Has Changed! Also Crucifixion, yes. | Roblox Doors Hotel Update",
    "ONE COLOR Hide & Seek In ROBLOX!",
    "DOORS: The Movie: A Roblox Horror Movie",
    "Escape EVIL LUNCH LADY OBBY in Roblox",
    "Top 13 Roblox Horror Games to play with friends (Roblox horror games multiplayer)",
    "ROBLOX DEVELOPERS AS THE SEVEN DEADLY SINS",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "Roblox Games You've Probably Forgot About..",
    "Roblox the presentation experience: more robux actions and some chaos",
    "Roblox | Brookhaven RP | ALL OF US ARE DEAD",
    "How to get ALL the Twice Emotes in roblox",
    "How To FIND ALL 7 NEW UPDATE FOOD LOCATIONS In Roblox Secret Staycation!",
    "😱 All NEW CODES In Super League Soccer! 😱 | ROBLOX",
    "ROBLOX - Weird Strict Dad All Jumpscares and Scary Moments",
    "All Roblox Error Codes (Explained)",
    "Roblox Games You've Probably Forgot About..",
    "Roblox the presentation experience: more robux actions and some chaos",
    "This Ghost Has The Finger Painter Badge...",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "Roblox The Mimic All Books Jumpscare (Including Jigoku, NM mode, Game mode)",
    "ROBLOX : IT'S FREE",
    "ROBLOX-Broken Bones 2:All Secret Maps.",
    "ROBLOX - IShowSpeed got BILLIONS of Robux reaction",
    "ESCAPE BARKY THE DOG OBBY | Roblox",
    "10 Best Roblox Horror Games 2022 (Scary Roblox Games)",
    "ONE COLOR Hide & Seek In ROBLOX!",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "Dude Theft Wars All The Ghost In This Game !!! 👻👻👻",
    "The Watchtower Experience - Roblox -[All Endings]",
    "How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation",
    "ROBLOX NPCs are becoming smart! - 5 NEW Halloween Endings",
    "POV: Scary Jane (The Fake Mary) realizes you maxed your stats. Roblox Break In Chapter 2",
    "How to beat Residence Massacre Night 1 Without Bugs",
    "10 Best Roblox Horror Games 2022 (Scary Roblox Games)",
    "ALL 21 BOOMBOX CODES 2021 | Roblox Animal Simulator",
    "The NEW Roblox Skibidi Toilet Siege Defense UPDATE!",
    "DOORS: The Movie: A Roblox Horror Movie",
    "The Darkest Horror Game on Roblox",
    "How To Get All Foods Skins (All Foods Locations) In Secret Staycation | ROBLOX Secret Staycation",
    "GIVING PEOPLE THE WORST HAIRCUTS IN ROBLOX NEIGHBORS..",
    "The Hotel Has Changed! Also Crucifixion, yes. | Roblox Doors Hotel Update",
    "The Watchtower Experience - Roblox -[All Endings]",
    "Trapped in GIRLS ONLY Prison! (Roblox)",
    "How to get the Back On Track badge(detailed guide with info on a-60,a-90 & a-120) | DOORS ROBLOX",
    "How to get titan assistance badge! in Skbidi Toilet RP Roblox.",
    "Me and my family did this trend Part 2",
    "ROBLOX Brookhaven 🏡RP - FUNNY MOMENTS: RICH and POOR Full Episodes 4",
    "ROBLOX - Weird Strict Dad All Jumpscares and Scary Moments",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "HOW TO GET 'Haunted Harvester' FOR FREE! - Blade Ball (Roblox)",
    "Roblox The Mimic All Books Jumpscare (Including Jigoku, NM mode, Game mode)",
    "Roblox raise a floppa Full Game",
    "TOP 30 *WORKING* 2023 BLOXBURG NEIGHBORHOOD CODES!! | Roblox Bloxburg",
    "I Played 50 Roblox Anime Games",
    "The 10 strangest secrets in - break in 2 | Roblox",
    "ROBLOX - Faithless [ALL ENDINGS] - [Full Walkthrough]",
    "this roblox game FINALLY updated...",
    "How To Redeem Rogold Ultimate (Roblox)",
    "Mortal Kombat 1 - ALL Omni-Man Skins and Gears",
    "Obby But You're on a Car in Roblox",
    "I Escaped From Barry's Prison | Roblox Gameplay",
    "Hogwarts Legacy - Visiting Azkaban",
    "[ROBLOX UPDATES] FREE MINI PLUSHIES / FREE HAIR / FREE EMOTES / FREE HEADLESS 🤩👏",
    "Assassin's Creed - Every Iconic Assassinations",
    "5 *NEW* PLS DONATE GIFTBUX CODES IN ROBLOX 2023",
    "😱 All NEW CODES In Super League Soccer! 😱 | ROBLOX",
    "FASTEST WAY To Get Your FIRST 4K And 20 BOMB BADGES - Apex Legends!!",
    "SECRET UPDATE | POLICE GIRL RIP? Police Family Escape (OBBY) Full Game ROBLOX #roblox #obby",
    "LOCKDOWN (Roblox Movie) | Brookhaven RP",
    "Speaker family only challenge (Roblox Toilet Tower Defense)",
    "Roblox Doors Floor 1 : The Hotel |Akuma Demon|",
    "How to make a Citation System ( ROBLOX )",
    "Top 10 NEW Scary Roblox Games in 2022",
    "Malk (Interminable Rooms Meme)",
    "they live in a HAUNTED HOUSE",
    "Buying EVERY Vehicle and Car in ROBLOX Vehicle Legends!",
    "I Played 50 Roblox Anime Games",
    "How To Get SSJ Rage In Dragon Soul | Roblox",
    "Roblox Outfit Ideas Compilation #1",
    "Roblox: GREAT SCHOOL BREAKOUT Hardmode 1st POV",
    "Hanafi Muslim Massacre"
    ]

    cache = load_cache()

    # Setup Google Sheets access
    scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
    creds_path = 'D:\\Downloads\\ytfaceless-videos-2945d11a6940.json'
    creds = ServiceAccountCredentials.from_json_keyfile_name(creds_path, scope)
    client = gspread.authorize(creds)
    spreadsheet = client.open_by_key('1SBhFjGkUuo8CItepFC0PgFyRKyyCKO3pOkMErk4D7w4')
    worksheet = spreadsheet.get_worksheet(2)  # Accessing Sheet3 (index 2)

    all_video_data = []
    for title in video_titles:
        results = youtube_search(api_key, title, cache)
        for result in results:
            all_video_data.append([result[0], result[1], result[2]])

    save_cache(cache)
    # Append all video data to Sheet3
    for data in all_video_data:
        worksheet.append_row(data)

if __name__ == '__main__':
    main()
# Out:
# An HTTP error 403 occurred:
# b'{\n  "error": {\n    "code": 403,\n    "message": "The request cannot be completed because you have exceeded your \\u003ca href=\\"/youtube/v3/getting-started#quota\\"\\u003equota\\u003c/a\\u003e.",\n    "errors": [\n      {\n        "message": "The request cannot be completed because you have exceeded your \\u003ca href=\\"/youtube/v3/getting-started#quota\\"\\u003equota\\u003c/a\\u003e.",\n        "domain": "youtube.quota",\n        "reason": "quotaExceeded"\n      }\n    ]\n  }\n}\n'
# An HTTP error 403 occurred:
# ...
